# %% [markdown]
# <a href="https://colab.research.google.com/github/KhushbooGupta2111/Data-Visualization/blob/master/Customer_Segment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Libraries

# %%
pip install dabl

# %%
#for dataframe manipulations 
import numpy as np 
#for mathematical operation
import pandas as pd  
#for Data Visualisation     
import matplotlib.pyplot as plt   
import seaborn as sns 
plt.style.use('fivethirtyeight')
#for data analytics
import dabl

# %% [markdown]
# Importing Dataset

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Reading Dataset

# %%
auto_data = pd.read_csv('gdrive/My Drive/Indian automoble buying behavour study 1.0.csv')

# %% [markdown]
# Examining Dataset

# %%
print("Shape of dataset :", auto_data.shape)
# Out:
# Shape of dataset : (99, 13)

# %%
auto_data.head()
# Out:
#    Age Profession Marrital Status      Education  No of Dependents  \
# 0   27   Salaried          Single  Post Graduate                 0
# 1   35   Salaried         Married  Post Graduate                 2
# 2   45   Business         Married       Graduate                 4
# 3   41   Business         Married  Post Graduate                 3
# 4   31   Salaried         Married  Post Graduate                 2
#
#   Personal loan House Loan Wife Working   Salary  Wife Salary  Total Salary  \
# 0           Yes         No           No   800000            0        800000
# 1           Yes        Yes          Yes  1400000       600000       2000000
# 2           Yes        Yes           No  1800000            0       1800000
# 3            No         No          Yes  1600000       600000       2200000
# 4           Yes         No          Yes  1800000       800000       2600000
#
#      Make    Price
# 0     i20   800000
# 1    Ciaz  1000000
# 2  Duster  1200000
# 3    City  1200000
# 4     SUV  1600000

# %%
sns.pairplot(auto_data)
plt.show()

# %%
sns.heatmap(auto_data.corr(), annot = True)
plt.title("Correlation  Heatmap of the data", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Correlation  Heatmap of the data')

# %%
dabl.plot(auto_data,target_col = "Salary")
# Out:
# Target looks like classification
# [[<Figure size 216x216 with 2 Axes>], None]

# %% [markdown]
# Data Cleaning

# %%
auto_data.isnull().any().any()
# Out:
# False

# %%
# This function is used to eliminate the delimiter values in the columns
def unit_delimiter(column_name , removing_substring):
  auto_data[column_name] = auto_data[column_name].apply(str).str.replace(' ' + removing_substring , '');

# %% [markdown]
# Function Built for converting values from string to integer 🌻
#
# (Note: Run this after you have executed the function unit_delimiter)

# %%
def string_to_numeric(column_name):
  auto_data[column_name] = auto_data[column_name].fillna(0)
  auto_data[column_name] = auto_data[column_name].replace("nan" , 0 , regex = True)
  auto_data[column_name] = pd.to_numeric(auto_data[column_name] )

# %% [markdown]
# Data Visualization

# %%
string_to_numeric('Make')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "i20"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-279933ece609> in <module>()
# ----> 1 string_to_numeric('Make')
#
# <ipython-input-23-65acaf98fb17> in string_to_numeric(column_name)
#       2   auto_data[column_name] = auto_data[column_name].fillna(0)
#       3   auto_data[column_name] = auto_data[column_name].replace("nan" , 0 , regex = True)
# ----> 4   auto_data[column_name] = pd.to_numeric(auto_data[column_name] )
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     182         try:
#     183             values, _ = lib.maybe_convert_numeric(
# --> 184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#     186         except (ValueError, TypeError):
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "i20" at position 0

# %%
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = (18,8)
plt.subplot(1,2,1)
sns.set(style = 'whitegrid')
sns.distplot(auto_data['Total Salary'])
plt.title('Distribution of Make', fontsize = 30)
plt.xlabel('Car names')
plt.ylabel('No of cars sold')
# Out:
# Text(0, 0.5, 'No of cars sold')
